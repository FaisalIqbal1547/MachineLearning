# %% [markdown]
# <a href="https://colab.research.google.com/github/FaisalIqbal1547/MachineLearning/blob/main/tutorial10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from sklearn.datasets import load_iris
iris = load_iris()
dir(iris)
# Out:
# ['DESCR',
#  'data',
#  'data_module',
#  'feature_names',
#  'filename',
#  'frame',
#  'target',
#  'target_names']

# %%
iris.feature_names
# Out:
# ['sepal length (cm)',
#  'sepal width (cm)',
#  'petal length (cm)',
#  'petal width (cm)']

# %%
df = pd.DataFrame(iris.data, columns=iris.feature_names)
# my data is in iris.data and we have arrange the data with features names in the column
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
#now I am adding the target

# %%
#here I am appending the df table
df['target'] = iris.target
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                5.1               3.5  ...               0.2       0
# 1                4.9               3.0  ...               0.2       0
# 2                4.7               3.2  ...               0.2       0
# 3                4.6               3.1  ...               0.2       0
# 4                5.0               3.6  ...               0.2       0
#
# [5 rows x 5 columns]

# %%
iris.target_names
#here we will get the target names means our output
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
df[df.target==0] # here I have 150 data and for setosa I have data from 0-50
df[df.target==1] # 50-99 we have data for versicolor
df[df.target==2] # 100-149 we have data for virginica
# Out:
#     sepal length (cm)  sepal width (cm)  ...  petal width (cm)  target
# 0                 5.1               3.5  ...               0.2       0
# 1                 4.9               3.0  ...               0.2       0
# 2                 4.7               3.2  ...               0.2       0
# 3                 4.6               3.1  ...               0.2       0
# 4                 5.0               3.6  ...               0.2       0
# 5                 5.4               3.9  ...               0.4       0
# 6                 4.6               3.4  ...               0.3       0
# 7                 5.0               3.4  ...               0.2       0
# 8                 4.4               2.9  ...               0.2       0
# 9                 4.9               3.1  ...               0.1       0
# 10                5.4               3.7  ...               0.2       0
# 11                4.8               3.4  ...               0.2       0
# ...
